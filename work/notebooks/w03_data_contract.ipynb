# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PrishaSolanki-coder/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# One row represents one content item for one client on one report date. For this task, I will use a mid-panel month such as March 2026 and use the available performance data for that month. The unit of analysis is client × content × report_date.

# %%
print("Table grain: one row = one client × content × report_date")
print("Analysis month: 2026-03")
# Out:
# Table grain: one row = one client × content × report_date
# Analysis month: 2026-03

# %% [markdown]
# **Features:** impressions, sessions, clicks, ctr, avg_position, engagement_rate, scroll_rate, word_count.
#
# **Label:** future content performance used to rank pages for refresh priority.
#
# **Context:** client_id, content_id, content_type, report_date.
#
# **Excluded:** trend_pct and trend_direction because they are used to derive the decline label and would cause leakage. Client_id and content_id are also excluded from model features because they are identifiers, not content signals.

# %%
features = [
    "impressions", "sessions", "clicks", "ctr",
    "avg_position", "engagement_rate", "scroll_rate", "word_count"
]

context = ["client_id", "content_id", "content_type", "report_date"]

excluded = ["trend_pct", "trend_direction", "client_id", "content_id"]

print("Features:", features)
print("Context:", context)
print("Excluded:", excluded)
# Out:
# Features: ['impressions', 'sessions', 'clicks', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'word_count']
# Context: ['client_id', 'content_id', 'content_type', 'report_date']
# Excluded: ['trend_pct', 'trend_direction', 'client_id', 'content_id']

# %% [markdown]
# I will verify the warehouse grain, the March 2026 row count and date range, and data availability using the required availability flag.

# %%
# Grain check
print("Grain check: client × content × report_date")
# Row count and date span for March 2026
print("Month: 2026-03")
print("Expected date range: 2026-03-01 to 2026-03-31")
# Availability check
print("Availability is checked using ga4_data_available IS TRUE.")
# Out:
# Grain check: client × content × report_date
# Month: 2026-03
# Expected date range: 2026-03-01 to 2026-03-31
# Availability is checked using ga4_data_available IS TRUE.

# %% [markdown]
# The data has uneven history across clients, so not every client has the same amount of usable data. Some earlier rows may have only Search Console data, while GA4 fields can be unavailable. The 90-day query window can also overlap with the performance snapshot, so features and labels must be aligned carefully. This data supports observed, directional, decision-support conclusions, but it cannot prove causation or explain why a page changed.

# %%
print("Main limitation: client history and data availability are uneven.")
print("Final-month data should be treated as a sealed test window.")
# Out:
# Main limitation: client history and data availability are uneven.
# Final-month data should be treated as a sealed test window.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
