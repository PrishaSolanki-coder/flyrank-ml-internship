# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PrishaSolanki-coder/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# My lane is ranking/scoring. The goal is to score content pages by their priority for an editor, so the pages most likely to need attention can be handled first.

# %%
print("Task type: Ranking / scoring")

# %% [markdown]
# The target is a priority score based on observed future content performance. The outcome should be measured in a later time window, not defined using the same signals used as features.

# %%
print("Target: future observed content performance")

# %% [markdown]
# The success metric is Precision@20. A good model should place a high proportion of truly important pages in the top 20 results.

# %%
print("Success metric: Precision@20")

# %% [markdown]
# The unit of analysis is one content item. Each row represents one pseudonymized content page and its available performance and content signals.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

df.head()

# %% [markdown]
# A fixed rule such as "stale and visible" uses only a small number of signals. ML can combine multiple signals and learn patterns that are difficult to express with one if-statement. This can help editors prioritize pages more effectively.

# %%
All sections are filled. The task type, target, success metric, unit of analysis, and reason for using ML are defined. The notebook uses the starter dataset and avoids using trend_pct or trend_direction as features.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✅] Every section above is filled — markdown thinking AND the code that backs it
# - [✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✅] No client names, URLs, or private queries anywhere
# - [✅] My claims use careful words: observed, measured, directional, decision-support
# - [✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
