# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PrishaSolanki-coder/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# **Lane 2: Refresh / Content Opportunity Scoring**
#
# I chose this lane because it focuses on identifying which pages should be reviewed first for refresh, expansion, protection, pruning, or monitoring. The starter dataset contains the search and content signals needed to investigate this question.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
df.head()

# %% [markdown]
# The decision is which pages should be prioritized for review. A content or SEO team could use the ranking to decide which pages to review first and what action they may need. A wrong recommendation could waste review time or cause an important page to be overlooked.

# %%
print("Pages:", df["content_id"].nunique())
print("Average impressions:", round(df["impressions_90d"].mean(), 2))
print("Average sessions:", round(df["sessions_90d"].mean(), 2))

# %% [markdown]
# The starter dataset contains observable content and search-performance signals. It has enough page-level information, including impressions and sessions, to investigate which pages may deserve review and prioritization.

# %%
print("Total observations:", len(df))
print("Pages with impressions:", (df["impressions_90d"] > 0).sum())
print("Pages with sessions:", (df["sessions_90d"] > 0).sum())

# %% [markdown]
# I can identify observed patterns and provide directional, evidence-based decision-support for prioritizing pages. I cannot claim that the results prove causation, guarantee that a page will recover, or prove Google algorithm factors

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))

print("Columns:", len(df.columns))

df.head()

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
